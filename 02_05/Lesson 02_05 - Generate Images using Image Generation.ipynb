# %% [markdown]
# # Building a Project with the ChatGPT API

# %% [markdown]
# ## Lesson Examples

# %% [markdown]
# ### Install the necessary libraries.

# %%
pip install openai

# %%
pip install openai[datalib]

# %%
pip install urllib3==1.26.6

# %%
pip install python-dotenv

# %% [markdown]
# ### Import the libraries and environment file to gain access to the Open API Key
# #### The key can be generated here: https://platform.openai.com/account/api-keys

# %%
import os
from openai import OpenAI

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file

# %% [markdown]
# ### Authenticate to the API using the API Key
# #### Pull from environment variables or use api_key = ("your_key_here") to hardcode the key

# %%
client = OpenAI(
  api_key=os.environ['OPENAI_API_KEY']  
)

# %% [markdown]
# ## 02_05 - Generate Images using Image Generation

# %% [markdown]
# ### Create Image

# %%
from IPython.display import Image

response = client.images.generate(
  model="dall-e-2",
  prompt="a rainbow with a pot of gold",
  size="256x256",
  quality="standard",
  n=1, #select the number of images you want generated
)

image_url = response.data[0].url

print(image_url)

Image(url=image_url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-vT2QsmZLYUF3KV5YFOxNgt1f/user-ZKD2PcmRE6CmmOGdHzFUQ0fF/img-EH0BklTApV7NeUzXPJcYm2ne.png?st=2025-02-11T21%3A29%3A34Z&se=2025-02-11T23%3A29%3A34Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-02-11T09%3A58%3A05Z&ske=2025-02-12T09%3A58%3A05Z&sks=b&skv=2024-08-04&sig=kKxTyE4SN7tB4uIzLU3Hcg8kNwMV6cXdxdqgdlOQR2o%3D
# <img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-vT2QsmZLYUF3KV5YFOxNgt1f/user-ZKD2PcmRE6CmmOGdHzFUQ0fF/img-EH0BklTApV7NeUzXPJcYm2ne.png?st=2025-02-11T21%3A29%3A34Z&se=2025-02-11T23%3A29%3A34Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-02-11T09%3A58%3A05Z&ske=2025-02-12T09%3A58%3A05Z&sks=b&skv=2024-08-04&sig=kKxTyE4SN7tB4uIzLU3Hcg8kNwMV6cXdxdqgdlOQR2o%3D"/>

# %% [markdown]
# ### Edit an Image

# %%
Image(url="hawaii.png") #original image
# Out:
# <img src="hawaii.png"/>

# %%
from PIL import Image

# resize original image - mask size must match image size
image = Image.open("hawaii.png")
hawaii_resized = image.resize((1024, 1024))
hawaii_resized.save("hawaii_1024.png")


# edit the video to include a beach chair w/ umbrella
response = client.images.edit(
  model="dall-e-2",
  image=open("hawaii_1024.png", "rb"),
  mask=open("mask.png", "rb"), # Edit requires a "mask" to specify which portion of the image to regenerate
                               # This mask covers the bottom half of an image
  prompt="A beach chair with an umbrella",
  n=1,
  size="1024x1024"
)
image_url = response.data[0].url

print(image_url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-vT2QsmZLYUF3KV5YFOxNgt1f/user-ZKD2PcmRE6CmmOGdHzFUQ0fF/img-mW3wKO4wgz6paqigUJ0dlHl3.png?st=2025-02-11T21%3A31%3A20Z&se=2025-02-11T23%3A31%3A20Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-02-11T13%3A08%3A53Z&ske=2025-02-12T13%3A08%3A53Z&sks=b&skv=2024-08-04&sig=964QN2aoh9PNphXd3XGiR%2BrccJEbSBgCf88yyV3mvD4%3D

# %%
from IPython.display import Image

Image(url=image_url) #display edited image
# Out:
# <img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-vT2QsmZLYUF3KV5YFOxNgt1f/user-ZKD2PcmRE6CmmOGdHzFUQ0fF/img-mW3wKO4wgz6paqigUJ0dlHl3.png?st=2025-02-11T21%3A31%3A20Z&se=2025-02-11T23%3A31%3A20Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-02-11T13%3A08%3A53Z&ske=2025-02-12T13%3A08%3A53Z&sks=b&skv=2024-08-04&sig=964QN2aoh9PNphXd3XGiR%2BrccJEbSBgCf88yyV3mvD4%3D"/>

# %% [markdown]
# ### Create Image Variation

# %% [markdown]
# #### Uploaded image must be a PNG and less than 4 MB.

# %%
Image(url="hawaii.png") #original image
# Out:
# <img src="hawaii.png"/>

# %%
response = client.images.create_variation(
  image=open("hawaii.png", "rb"),
  n=1,
  size="1024x1024"
)

image_url = response.data[0].url

print(image_url)

Image(url=image_url) #edited image
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-vT2QsmZLYUF3KV5YFOxNgt1f/user-ZKD2PcmRE6CmmOGdHzFUQ0fF/img-6QpdZhwspSLzY3kMPdumxhnC.png?st=2025-02-11T21%3A32%3A42Z&se=2025-02-11T23%3A32%3A42Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-02-11T18%3A57%3A48Z&ske=2025-02-12T18%3A57%3A48Z&sks=b&skv=2024-08-04&sig=TeirR0GTJlojRKmWh5fPOVuVRBlqEURAAXBRZCHzL%2BE%3D
# <img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-vT2QsmZLYUF3KV5YFOxNgt1f/user-ZKD2PcmRE6CmmOGdHzFUQ0fF/img-6QpdZhwspSLzY3kMPdumxhnC.png?st=2025-02-11T21%3A32%3A42Z&se=2025-02-11T23%3A32%3A42Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-02-11T18%3A57%3A48Z&ske=2025-02-12T18%3A57%3A48Z&sks=b&skv=2024-08-04&sig=TeirR0GTJlojRKmWh5fPOVuVRBlqEURAAXBRZCHzL%2BE%3D"/>
